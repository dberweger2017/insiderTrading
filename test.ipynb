# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import json
import os

# %%
# load consolidated_growth.csv
df = pd.read_csv('consolidated_growth.csv')

# remove rows that all columns 1d,1w,1m,6m,5d,10d,20d,60d,120d,240d,360d are NaN
df = df.dropna(how='all', subset=['1d', '1w', '1m', '6m', '5d', '10d', '20d', '60d', '120d', '240d', '360d'])
df
# Out:
# /var/folders/60/df0y9d9s5rjfqhlhkzn3l6p40000gn/T/ipykernel_35781/1437175252.py:2: DtypeWarning: Columns (14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('consolidated_growth.csv')
#           X          Filing Date  Trade Date Ticker  \
# 1         M  2003-07-28 09:08:53  2003-07-21   PLUG
# 5       NaN  2003-07-28 10:26:12  2003-07-25    OCN
# 13      NaN  2003-07-28 10:44:07  2003-07-25    NVR
# 14      NaN  2003-07-28 10:53:22  2003-07-25     GD
# 15      NaN  2003-07-28 10:54:27  2003-07-24    FCS
# ...     ...                  ...         ...    ...
# 959177  NaN  2017-05-12 15:43:45  2017-05-12   UBCP
# 959178  NaN  2017-05-12 15:48:51  2017-05-12    CUI
# 959179  NaN  2017-05-12 15:48:54  2017-05-10   TREX
# 959180  NaN  2017-05-12 15:52:50  2017-05-10   EDGW
# 959181  NaN  2017-05-12 15:57:06  2017-05-10    RYN
#
#                                      Company Name               Insider Name  \
# ...
